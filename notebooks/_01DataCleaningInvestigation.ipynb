# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
df = pd.read_json("../data/Appliances.json", lines = True)
df.head(10)
# Out:
#    overall vote  verified   reviewTime      reviewerID        asin  \
# 0        5    2     False  11 27, 2013  A3NHUQ33CFH3VM  1118461304
# 1        5  NaN     False   11 1, 2013  A3SK6VNBQDNBJE  1118461304
# 2        5  NaN     False  10 10, 2013  A3SOFHUR27FO3K  1118461304
# 3        5  NaN     False   10 9, 2013  A1HOG1PYCAE157  1118461304
# 4        5   10     False   09 7, 2013  A26JGAM6GZMM4V  1118461304
# 5        5  NaN     False  05 11, 2014  A17K8WANMYHTX2  1118461304
# 6        5  NaN     False   05 9, 2014  A13IW3A6W43U0G  1118461304
# 7        5  NaN      True   05 7, 2014  A1ECEGG1MP7J8J  1118461304
# 8        5  NaN     False   05 4, 2014  A2D5X9G9S3A7RN  1118461304
# 9        5  NaN     False   05 2, 2014   AP2F86JFRQ205  1118461304
#
#                             style              reviewerName  \
# 0       {'Format:': ' Hardcover'}                    Greeny
# 1  {'Format:': ' Kindle Edition'}           Leif C. Ulstrup
# 2       {'Format:': ' Hardcover'}  Harry Gilbert Miller III
# 3       {'Format:': ' Hardcover'}            Rebecca Ripley
# 4       {'Format:': ' Hardcover'}             Robert Morris
# 5       {'Format:': ' Hardcover'}            mark h wellman
# 6       {'Format:': ' Hardcover'}                       Mmf
# 7       {'Format:': ' Hardcover'}             G. Deatherage
# 8       {'Format:': ' Hardcover'}            Teresa Fritsch
# 9       {'Format:': ' Hardcover'}                Ken Harris
#
#                                           reviewText  \
# 0  Not one thing in this book seemed an obvious o...
# 1  I have enjoyed Dr. Alan Gregerman's weekly blo...
# 2  Alan Gregerman believes that innovation comes ...
# 3  Alan Gregerman is a smart, funny, entertaining...
# 4  As I began to read this book, I was again remi...
# 5  I teach a class on innovation and I used the N...
# 6  I so appreciated the insights and perspective ...
# 7  As with "Surrounded by Genius", Alan Gregerman...
# 8  Alan Gregermans book provides valuable ideas f...
# 9  I am a believer in Alan Gregerman.  I have enj...
#
#                                              summary  unixReviewTime image
# 0                  Clear on what leads to innovation      1385510400   NaN
# 1  Becoming more innovative by opening yourself t...      1383264000   NaN
# 2              The World from Different Perspectives      1381363200   NaN
# 3                Strangers are Your New Best Friends      1381276800   NaN
# 4  How and why it is imperative to engage, learn ...      1378512000   NaN
# 5                          Insightful & Very Useful!      1399766400   NaN
# 6                        The necessity of this book!      1399593600   NaN
# 7                           Great insight-Great book      1399420800   NaN
# 8  The Necessity of Strangers dares you to be ope...      1399161600   NaN
# 9                 Review: The Necessity of Strangers      1398988800   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 602777 entries, 0 to 602776
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   overall         602777 non-null  int64
#  1   vote            65262 non-null   object
#  2   verified        602777 non-null  bool
#  3   reviewTime      602777 non-null  object
#  4   reviewerID      602777 non-null  object
#  5   asin            602777 non-null  object
#  6   style           137973 non-null  object
#  7   reviewerName    602762 non-null  object
#  8   reviewText      602453 non-null  object
#  9   summary         602649 non-null  object
#  10  unixReviewTime  602777 non-null  int64
#  11  image           9258 non-null    object
# dtypes: bool(1), int64(2), object(9)
# memory usage: 51.2+ MB

# %%
df.isna().sum()
# Out:
# overall                0
# vote              537515
# verified               0
# reviewTime             0
# reviewerID             0
# asin                   0
# style             464804
# reviewerName          15
# reviewText           324
# summary              128
# unixReviewTime         0
# image             593519
# dtype: int64

# %%
# Drop rows with missing values in 'vote'
df = df.dropna(subset = ['vote'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 65262 entries, 0 to 602750
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   overall         65262 non-null  int64
#  1   vote            65262 non-null  object
#  2   verified        65262 non-null  bool
#  3   reviewTime      65262 non-null  object
#  4   reviewerID      65262 non-null  object
#  5   asin            65262 non-null  object
#  6   style           16065 non-null  object
#  7   reviewerName    65261 non-null  object
#  8   reviewText      65235 non-null  object
#  9   summary         65258 non-null  object
#  10  unixReviewTime  65262 non-null  int64
#  11  image           5213 non-null   object
# dtypes: bool(1), int64(2), object(9)
# memory usage: 6.0+ MB

# %%
# Fill missing values in 'style,' 'reviewerName,' 'reviewText,' and 'summary' with empty strings
df['style'].fillna('', inplace = True)
df['reviewerName'].fillna('', inplace = True)
df['reviewText'].fillna('', inplace = True)
df['summary'].fillna('', inplace = True)

# %%
# Convert 'vote' to numeric (assuming 'NaN' means 0)
df['vote'] = df['vote'].str.replace(',', '', regex=True).fillna(0).astype(int)

# Convert reviewTime
df['reviewTime'] = pd.to_datetime(df['reviewTime'], format = '%m %d, %Y')

# %%
# Extract year, month, and day from 'reviewTime'
df['reviewYear'] = df['reviewTime'].dt.year
df['reviewMonth'] = df['reviewTime'].dt.month
df['reviewDay'] = df['reviewTime'].dt.day

# %%
# Delete the 'image' column
df.drop('image', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 65262 entries, 0 to 602750
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   overall         65262 non-null  int64
#  1   vote            65262 non-null  int32
#  2   verified        65262 non-null  bool
#  3   reviewTime      65262 non-null  datetime64[ns]
#  4   reviewerID      65262 non-null  object
#  5   asin            65262 non-null  object
#  6   style           65262 non-null  object
#  7   reviewerName    65262 non-null  object
#  8   reviewText      65262 non-null  object
#  9   summary         65262 non-null  object
#  10  unixReviewTime  65262 non-null  int64
#  11  reviewYear      65262 non-null  int32
#  12  reviewMonth     65262 non-null  int32
#  13  reviewDay       65262 non-null  int32
# dtypes: bool(1), datetime64[ns](1), int32(4), int64(2), object(6)
# memory usage: 6.0+ MB

# %%
df.head()
# Out:
#     overall  vote  verified reviewTime      reviewerID        asin  \
# 0         5     2     False 2013-11-27  A3NHUQ33CFH3VM  1118461304
# 4         5    10     False 2013-09-07  A26JGAM6GZMM4V  1118461304
# 10        4     2      True 2014-04-11  A3VF3A5A3O04E1  1118461304
# 11        5     3     False 2014-03-20  A14DW5UMQ1M96O  1118461304
# 19        5     2      True 2014-01-08  A2I5QME4S7CLFI  1118461304
#
#                              style   reviewerName  \
# 0        {'Format:': ' Hardcover'}         Greeny
# 4        {'Format:': ' Hardcover'}  Robert Morris
# 10  {'Format:': ' Kindle Edition'}      spsanders
# 11       {'Format:': ' Hardcover'}   Mike Jannini
# 19       {'Format:': ' Hardcover'}       Laura F.
#
#                                            reviewText  \
# 0   Not one thing in this book seemed an obvious o...
# 4   As I began to read this book, I was again remi...
# 10  A compelling book about why we should not be a...
# 11  Alan Gregerman's consulting work and writings ...
# 19  I usually find business books a re-hash of the...
#
#                                               summary  unixReviewTime  \
# 0                   Clear on what leads to innovation      1385510400
# 4   How and why it is imperative to engage, learn ...      1378512000
# 10                              Strangely Interesting      1397174400
# 11                            The Power of Innovation      1395273600
# 19             A New Twist on Out-of-the Box Thinking      1389139200
#
#     reviewYear  reviewMonth  reviewDay
# 0         2013           11         27
# 4         2013            9          7
# 10        2014            4         11
# 11        2014            3         20
# 19        2014            1          8

# %%
# Handling duplicates
# Convert the 'style' column from dictionaries to strings
df['style'] = df['style'].apply(lambda x: str(x) if isinstance(x, dict) else x)

# Check for duplicate rows
print("Duplicate Rows:")
print(df.duplicated().sum())

# Remove duplicate rows
df = df.drop_duplicates()

# Reset the index if needed
df = df.reset_index(drop=True)

df.head()
# Out:
# Duplicate Rows:
# 3640
#    overall  vote  verified reviewTime      reviewerID        asin  \
# 0        5     2     False 2013-11-27  A3NHUQ33CFH3VM  1118461304
# 1        5    10     False 2013-09-07  A26JGAM6GZMM4V  1118461304
# 2        4     2      True 2014-04-11  A3VF3A5A3O04E1  1118461304
# 3        5     3     False 2014-03-20  A14DW5UMQ1M96O  1118461304
# 4        5     2      True 2014-01-08  A2I5QME4S7CLFI  1118461304
#
#                             style   reviewerName  \
# 0       {'Format:': ' Hardcover'}         Greeny
# 1       {'Format:': ' Hardcover'}  Robert Morris
# 2  {'Format:': ' Kindle Edition'}      spsanders
# 3       {'Format:': ' Hardcover'}   Mike Jannini
# 4       {'Format:': ' Hardcover'}       Laura F.
#
#                                           reviewText  \
# 0  Not one thing in this book seemed an obvious o...
# 1  As I began to read this book, I was again remi...
# 2  A compelling book about why we should not be a...
# 3  Alan Gregerman's consulting work and writings ...
# 4  I usually find business books a re-hash of the...
#
#                                              summary  unixReviewTime  \
# 0                  Clear on what leads to innovation      1385510400
# 1  How and why it is imperative to engage, learn ...      1378512000
# 2                              Strangely Interesting      1397174400
# 3                            The Power of Innovation      1395273600
# 4             A New Twist on Out-of-the Box Thinking      1389139200
#
#    reviewYear  reviewMonth  reviewDay
# 0        2013           11         27
# 1        2013            9          7
# 2        2014            4         11
# 3        2014            3         20
# 4        2014            1          8

# %%
df.info()
print("Duplicate Rows:")
print(df.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61622 entries, 0 to 61621
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   overall         61622 non-null  int64
#  1   vote            61622 non-null  int32
#  2   verified        61622 non-null  bool
#  3   reviewTime      61622 non-null  datetime64[ns]
#  4   reviewerID      61622 non-null  object
#  5   asin            61622 non-null  object
#  6   style           61622 non-null  object
#  7   reviewerName    61622 non-null  object
#  8   reviewText      61622 non-null  object
#  9   summary         61622 non-null  object
#  10  unixReviewTime  61622 non-null  int64
#  11  reviewYear      61622 non-null  int32
#  12  reviewMonth     61622 non-null  int32
#  13  reviewDay       61622 non-null  int32
# dtypes: bool(1), datetime64[ns](1), int32(4), int64(2), object(6)
# memory usage: 5.2+ MB
# Duplicate Rows:
# 0

# %%
# Printing unique values in style column
unique_styles = df['style'].unique()
print("Unique values in 'style' column:")
for style in unique_styles:
    print(style)
# Out:
# Unique values in 'style' column:
# {'Format:': ' Hardcover'}
# {'Format:': ' Kindle Edition'}
# {'Size:': ' 6 ft', 'Style:': ' (Old)'}
#
# {'Color:': ' 1 Pack'}
# {'Style:': ' Dryer Vent'}
# {'Size:': ' 6-Foot'}
# {'Size Name:': ' 5-Foot'}
# {'Style:': ' Extension Accessory'}
# {'Size:': ' 1 Kit'}
# {'Color:': ' Silver'}
# {'Size:': ' 48-inch'}
# {'Size:': ' 5-Foot'}
# {'Size:': ' 60 Inch'}
# {'Size:': ' 10-Foot'}
# {'Style Name:': ' Black'}
# {'Style Name:': ' Wine'}
# {'Style Name:': ' Black Granite'}
# {'Style Name:': ' Morning Rooster'}
# {'Style Name:': ' Red'}
# {'Style Name:': ' Fresh Brewed'}
# {'Style Name:': ' Chickadees'}
# {'Style Name:': ' Stainless Look'}
# {'Style Name:': ' Night Shift'}
# {'Style Name:': ' White'}
# {'Style Name:': ' New Hope'}
# {'Style Name:': ' Pink'}
# {'Style Name:': ' Perfect Day'}
# {'Style Name:': ' Rooster & Copper Kettle'}
# {'Style Name:': ' Morning Run'}
# {'Style Name:': ' Rooster'}
# {'Style Name:': ' Almond'}
# {'Style Name:': ' New Fruit'}
# {'Color:': ' White'}
# {'Size:': ' 25 Watts', 'Color:': ' Soft White', 'Style:': ' Appliance'}
# {'Size:': ' 15 Watts', 'Color:': ' Warm White', 'Style:': ' Appliance'}
# {'Size:': ' 40 Watts', 'Color:': ' Daylight Clear', 'Style:': ' Fridge/Freezer'}
# {'Color:': ' Stainless Steel'}
# {'Color:': ' Black'}
# {'Size:': ' 72-Feet'}
# {'Style:': ' Standard'}
# {'Package Type:': ' Standard Packaging'}
# {'Size:': ' 1 Pack'}
# {'Size:': ' 4-Foot'}
# {'Style Name:': ' 3-Pack'}
# {'Style Name:': ' 2-Pack'}
# {'Color:': ' Almond'}
# {'Size:': ' 30-Inch', 'Color:': ' Stainless Steel'}
# {'Size:': ' 36-Inch', 'Color:': ' Stainless Steel'}
# {'Size:': ' 24-Inch', 'Color:': ' Stainless Steel'}
# {'Size:': ' 30-Inch', 'Color:': ' White'}
# {'Size:': ' 24-Inch', 'Color:': ' White'}
# {'Size:': ' 30-Inch', 'Color:': ' Black'}
# {'Size:': ' 36-Inch', 'Color:': ' Black'}
# {'Size:': ' 30-Inch', 'Color:': ' Biscuit'}
# {'Size:': ' 42-Inch', 'Color:': ' White'}
# {'Size:': ' 36-Inch', 'Color:': ' Bisque'}
# {'Size:': ' 6 ft', 'Style:': ' 6-Foot, 3-Wire'}
# {'Size:': ' 4 Filters'}
# {'Color:': ' Bisque'}
# {'Color:': ' Off-White'}
# {'Style:': ' 30-in'}
# {'Style:': ' 18-in'}
# {'Style:': ' 36-in'}
# {'Style:': ' 24-in'}
# {'Color:': ' Shadow Iris', 'Style Name:': ' Electric'}
# {'Color:': ' Abundance', 'Style Name:': ' Electric'}
# {'Color:': ' Pretty Pink', 'Style Name:': ' Gas'}
# {'Color:': ' Simple Lines', 'Style Name:': ' Electric'}
# {'Color:': ' Callaway', 'Style Name:': ' Electric'}
# {'Color:': ' Chutney', 'Style Name:': ' Electric'}
# {'Color:': ' Callaway', 'Style Name:': ' Gas'}
# {'Color:': ' Country Morning', 'Style Name:': ' Electric'}
# {'Size:': ' One Size', 'Color:': ' White'}
# {'Size:': ' 1 Pack (32 oz.)'}
# {'Size:': ' 36-Inch', 'Color:': ' White on White'}
# {'Size:': ' 30-Inch', 'Color:': ' White on White'}
# {'Size:': ' 42-Inch', 'Color:': ' Stainless Steel'}
# {'Size:': ' 24-Inch', 'Color:': ' Black'}
# {'Size:': ' 42-Inch', 'Color:': ' Almond'}
# {'Size:': ' 30-Inch', 'Color:': ' Bisque'}
# {'Size:': ' 42-Inch', 'Color:': ' White on White'}
# {'Size:': ' 42-Inch', 'Color:': ' Black'}
# {'Size:': ' 24-Inch', 'Color:': ' White on White'}
# {'Size:': ' 36-Inch', 'Color:': ' White'}
# {'Size:': ' 36-Inch', 'Color:': ' Biscuit on Biscuit'}
# {'Size:': ' 30-Inch', 'Color:': ' Biscuit on Biscuit'}
# {'Size:': ' 36-Inch', 'Color:': ' Almond'}
# {'Size:': ' 30-Inch', 'Color:': ' Black Steel'}
# {'Size:': ' 36-Inch', 'Color:': ' Black Steel'}
# {'Color:': ' White on White'}
# {'Size:': ' 1-Pack'}
# {'Size:': ' 24 by 24-Inch'}
# {'Size:': ' 24 by 30-Inch'}
# {'Size:': ' 24 by 42-Inch'}
# {'Size:': ' 24 by 36-Inch'}
# {'Size:': ' Filter E'}
# {'Style:': ' With Remote Probe'}
# {'Size:': ' Pack '}
# {'Size:': ' 25-Feet'}
# {'Size:': ' 4-Foot', 'Style:': ' (Old)'}
# {'Style:': ' Wrap Around'}
# {'Size:': ' 2-Pack'}
# {'Style:': ' Front Mount'}
# {'Size:': ' 2 Caps', 'Color:': ' Black'}
# {'Style Name:': ' Bacteriostat Solution'}
# {'Color:': ' stainless-steel'}
# {'Size Name:': ' 4 Inch'}
# {'Size:': ' 20 Inch'}
# {'Size:': ' 28-Inch x 30-Inch'}
# {'Color:': ' Oak'}
# {'Size:': ' Replacement Splashguard', 'Style:': ' Whirlaway and Sinkmaster'}
# {'Size:': ' Universal', 'Style:': ' Insinkerator'}
# {'Color:': ' Gray'}
# {'Color:': ' Stainless Steel/Silver'}
# {'Color:': ' Red'}
# {'Style:': ' Chrome'}
# {'Style:': ' Black Porcelain'}
# {'Size:': ' Poly Tubing', 'Style:': ' Supply Line Only'}
# {'Size:': ' Copper Tubing', 'Style:': ' Kit'}
# {'Size:': ' Poly Tubing', 'Style:': ' Kit'}
# {'Size:': ' Stainless Steel Tubing', 'Style:': ' Supply Line Only'}
# {'Style:': ' Clarinet/Saxophone'}
# {'Style:': ' Oboe/Bassoon'}
# {'Style:': ' Reed Vitalizer Refill'}
# {'Style:': ' Connector Kit'}
# {'Size:': ' 1 Pack', 'Color:': ' White'}
# {'Color:': ' black'}
# {'Color:': ' Stainless'}
# {'Size:': ' Pack of 5'}
# {'Size:': ' 30-Inch'}
# {'Size:': ' 36-Inch'}
# {'Size Name:': ' 30 Inch'}
# {'Size:': ' 39-Inch', 'Color:': ' Stainless Steel'}
# {'Size:': ' 48-Inch', 'Color:': ' Stainless Steel'}
# {'Size:': ' 30-Inch', 'Color:': ' Monochromatic White'}
# {'Size Name:': ' 24 Inch'}
# {'Color:': ' Bisque/Biscuit Monochromatic'}
# {'Size:': ' 1 Pack', 'Style Name:': ' Metal'}
# {'Size:': ' 1 Pack', 'Style Name:': ' Paper Wick'}
# {'Size:': ' Pack of 1'}
# {'Color:': ' Biscuit'}
# {'Package Quantity:': ' 1'}
# {'Size:': ' 30-Inch', 'Color:': ' Almond'}
# {'Size:': ' 30', 'Color:': ' Black'}
# {'Size:': ' 8-Inch'}
# {'Size:': ' 36 Inch', 'Color:': ' Black'}
# {'Size:': ' 40 Bags'}
# {'Color:': ' Chrome'}
# {'Color:': ' White', 'Size Name:': ' 6"'}
# {'Color:': ' Brown', 'Size Name:': ' 6"'}
# {'Color:': ' White', 'Size Name:': ' 8"'}
# {'Size:': ' Pack of 1', 'Color:': ' N/A'}
# {'Size:': ' Set of 4', 'Color:': ' Simple Lines'}
# {'Size:': ' Set of 4', 'Color:': ' Country Morning'}
# {'Color:': ' Orange'}
# {'Color:': ' Blue'}
# {'Size:': ' M815202039'}
# {'Size:': ' 16 oz.'}
# {'Size:': ' 16 oz'}
# {'Size:': ' M815203113'}
# {'Size:': ' M815203094'}
# {'Size:': ' TPB514170'}
# {'Size:': ' M815202104'}
# {'Size:': ' 3.52 Ounce'}
# {'Size:': ' 5 oz'}
# {'Size:': ' TPB514148'}
# {'Size:': ' 17 Fl.Oz.'}
# {'Size:': ' 2.5oz'}
# {'Size:': ' M815201010'}
# {'Color:': ' Brushed Stainless Steel'}
# {'Size:': ' 10-Pack'}
# {'Size:': ' 3-Pack'}
# {'Size:': ' 26 x 18 Inch'}
# {'Color:': ' White-on-White'}
# {'Size:': ' 250 CFM'}
# {'Size:': ' 390 CFM'}
# {'Size:': ' 1500 CFM 3.8-Amp'}
# {'Color:': ' 30-Inch, Stainless Steel'}
# {'Color:': ' 30-Inch, White'}
# {'Color:': ' 30-Inch, Almond'}
# {'Size:': ' 1 Count'}
# {'Size:': ' 2 Count'}
# {'Size:': ' 15-Inch', 'Style Name:': ' Pocket Thermometer'}
# {'Size:': ' 17-Inch', 'Style Name:': ' Refrigerator Thermometer'}
# {'Color:': ' Filter'}
# {'Size:': ' 1'}
# {'Size:': ' 15-Foot'}
# {'Size:': ' 25-Foot'}
# {'Size Name:': ' 6&quot;'}
# {'Size:': ' 42-Inch'}
# {'Size:': ' 48-Inch'}
# {'Size:': ' 19.44 Inch'}
# {'Size:': ' 31.13 Inch'}
# {'Color:': ' Polished Stainless Steel'}
# {'Size:': ' 3.5 Cubic Foot Chest Freezer', 'Color:': ' White'}
# {'Size:': ' 5.1 Cubic Foot Chest Freezer', 'Color:': ' White'}
# {'Size:': ' 7.1 Cubic Foot Chest Freezer', 'Color:': ' Black'}
# {'Size:': ' 7.1 Cubic Foot Chest Freezer', 'Color:': ' White'}
# {'Size:': ' 10.6 Cubic Foot Chest Freezer', 'Color:': ' White'}
# {'Color:': ' Stainless Look'}
# {'Color:': ' Wines and Vines'}
# {'Color:': ' Mutli-color'}
# {'Color:': ' Morning Run'}
# {'Color:': ' 8'}
# {'Color:': ' 10'}
# {'Color:': ' blue'}
# {'Color:': ' Grey'}
# {'Style:': ' Temperature and Humidity'}
# {'Style:': ' Temperature'}
# {'Size:': ' 900 CFM 5.7-Amp'}
# {'Size:': ' 60 Bags', 'Style:': ' 15 Inches/W10165294RB'}
# {'Size:': ' 60 Bags', 'Style:': ' 18 Inches'}
# {'Size:': ' 8 Bags', 'Style:': ' 15 Inches'}
# {'Size:': ' 60 Bags', 'Style:': ' 15 Inches/W10351674RB'}
# {'Size:': ' 8 Bags', 'Style:': ' 15 Inches/With Odor Remover'}
# {'Size:': ' 15 Bags', 'Style:': ' 15 Inches'}
# {'Size:': ' 180 Bags', 'Style:': ' 15 Inches/With Odor Remover'}
# {'Size:': ' 3-1/2" W x 5-1/2" H', 'Color:': ' Multicolor'}
# {'Size:': ' 5100 Economy'}
# {'Color:': ' Satin Nickel'}
# {'Color:': ' Steel Brushed Nickel'}
# {'Color:': ' Oil-Rubbed Bronze'}
# {'Color:': ' Black/Stainless'}
# {'Size Name:': ' 1-Pack'}
# {'Size:': ' 400 CFM', 'Color:': ' Stainless'}
# {'Size:': ' 5.3 cu. ft.'}
# {'Size Name:': ' 1 Pack'}
# {'Color:': ' Flat Stainless Steel Door'}
# {'Color:': ' Flat Black Door'}
# {'Size:': ' Universal, Chrome'}
# {'Size:': ' Gas'}
# {'Size:': ' Electric'}
# {'Size:': ' GE/Hotpoint, Chrome'}
# {'Size:': ' GE/Hotpoint, Porcelain'}
# {'Size:': ' Universal, Porcelain'}
# {'Size:': ' Universal, Non-Stick'}
# {'Size:': ' None', 'Color:': ' Red'}
# {'Color:': ' Stainless Steel and Black'}
# {'Style:': ' THWD-3'}
# {'Style:': ' THWD-5'}
# {'Size:': ' 29-Inch'}
# {'Size:': ' 27-Inch'}
# {'Color:': ' Brown', 'Size Name:': ' 4" Vent Hood'}
# {'Color:': ' Brown', 'Size Name:': ' 4" Vent Cap'}
# {'Color:': ' White', 'Size Name:': ' 4" Vent Hood'}
# {'Color:': ' Coffee'}
# {'Color:': ' Rooster'}
# {'Size:': ' 8 Inch'}
# {'Size:': ' 10 Inch'}
# {'Size:': ' ONE'}
# {'Size:': ' TWO'}
# {'Size:': ' 1 Faucet with Tank', 'Color:': ' Standard'}
# {'Size:': ' 1 Faucet with Tank', 'Color:': ' Deluxe'}
# {'Size:': ' 1 Faucet without Tank', 'Color:': ' Standard'}
# {'Size:': ' 2 Faucet with Tank', 'Color:': ' Standard'}
# {'Size:': ' 2 Faucet with Tank', 'Color:': ' Deluxe'}
# {'Size:': ' 2 Faucet without Tank', 'Color:': ' Standard'}
# {'Size:': ' 1', 'Color:': ' Ultimate'}
# {'Size:': ' 12-5/8 Inch'}
# {'Size:': ' 14-1/2 Inch'}
# {'Size:': ' 6 Inch'}
# {'Color:': ' Beige'}
# {'Color:': ' Black-on-Black'}
# {'Size:': ' 1 - Pack'}
# {'Size:': ' full'}
# {'Color:': ' Yellow'}
# {'Size:': ' 72-inch'}
# {'Size:': ' Single Pack'}
# {'Size:': ' 2 pack'}
# {'Size:': ' 1', 'Color:': ' Black'}
# {'Size:': ' 2-inch', 'Color:': ' Black'}
# {'Size:': ' 2-inch & 1 1/2-inch', 'Color:': ' Black'}
# {'Size:': ' 1 1/2-inch', 'Color:': ' Plum'}
# {'Color:': ' Black/ Platinum Laminet finish on door'}
# {'Size:': ' 00755060 (or 492332)', 'Color:': ' Black'}
# {'Size:': ' WB20T10025', 'Color:': ' Gray'}
# {'Size:': ' 318601302', 'Color:': ' Black'}
# {'Size:': ' 9755542', 'Color:': ' Brown'}
# {'Style:': ' 2-Pack'}
# {'Style:': ' 3-Pack'}
# {'Style:': ' 1 Pack'}
# {'Style:': ' 3 Pack'}
# {'Style Name:': ' 2 Pack'}
# {'Size:': ' 10.80in. x 6.50in. x 5.90in.'}
# {'Color:': ' N/A'}
# {'Style Name:': ' 26 lbs of Ice per day'}
# {'Style:': ' 48 lbs of Ice per day'}
# {'Size:': ' 2 Faucet without Tank', 'Color:': ' Stainless Steel'}
# {'Style:': ' Valve Coil'}
# {'Color:': ' stainless steel'}
# {'Size:': ' 1-(Pack)'}
# {'Size:': ' WashBasin'}
# {'Color:': ' Polished Chrome'}
# {'Size:': ' 2 Faucet', 'Color:': ' Black'}
# {'Size:': ' 2 Faucet', 'Color:': ' Stainless Steel'}
# {'Size:': ' 1 Faucet', 'Color:': ' Stainless Steel'}
# {'Color:': ' Black/Silver'}
# {'Size:': ' 5.5 lbs', 'Color:': ' Blue'}
# {'Size:': ' Stand', 'Color:': ' Taupe'}
# {'Size:': ' King', 'Color:': ' Taupe'}
# {'Size:': ' 1 Filter'}
# {'Size:': ' Beverage Cooler'}
# {'Size:': ' 4.00in. x 3.30in. x 3.10in.'}
# {'Color:': ' Black and Stainless Steel'}
# {'Pattern:': ' Replace 303373'}
# {'Size:': ' 10.30in. x 3.40in. x 3.00in.'}
# {'Style:': ' 1/2 HP direct wire waste disposer'}
# {'Style:': ' 1/3 HP direct wire waste disposer'}
# {'Style Name:': ' 1-Pack'}
# {'Style Name:': ' 4-Pack'}
# {'Style Name:': ' Sunbeam Bacteriostat Solution'}
# {'Style Name:': ' Sunbeam Combo Solution'}
# {'Style Name:': ' Sunbeam Water Treatment Solution'}
# {'Color:': ' white'}
# {'Size:': ' 30 Inch'}
# {'Size:': ' 36 Inch'}
# {'Style:': ' Premium 4'}
# {'Style:': ' Ventum 2'}
# {'Size:': " 10' Length"}
# {'Size:': ' 6 ft Length'}
# {'Size:': ' 5 ft Length'}
# {'Size:': ' Sonya 8.8 lbs Capacity/2.65 Cu.ft'}
# {'Style:': ' KIT WITH RIGIFLEXTM'}
# {'Size:': ' Panda 2.65 Cu.ft'}
# {'Size:': ' Ultrasonic repeller Model BH-3 Ver.36'}
# {'Size:': ' Ultrasonic repeller Model BH-3 Ver.225'}
# {'Size:': ' Ultrasonic repeller Model BH-3 Ver.2'}
# {'Size:': ' Ultrasonic repeller Model BH-3 Ver.3'}
# {'Size:': ' Ultrasonic repeller Model BH-3 Ver.270'}
# {'Package Quantity:': ' 1', 'Style Name:': ' Multicolored'}
# {'Package Quantity:': ' 1', 'Style Name:': ' White'}
# {'Color:': ' Multicolor'}
# {'Package Quantity:': ' 1', 'Style Name:': ' Black'}
# {'Size:': ' 42"'}
# {'Color:': ' Clear', 'Package Quantity:': ' 1'}
# {'Color:': ' Black', 'Package Quantity:': ' 1'}
# {'Color:': ' White', 'Package Quantity:': ' 1'}
# {'Size:': ' Sonya 13 lbs Capacity/3.75 Cu.ft'}
# {'Size:': ' 40 Pack'}
# {'Size:': ' 2 Pack'}
# {'Size:': ' 100 Pack'}
# {'Item Package Quantity:': ' 1', 'Package Quantity:': ' 1'}
# {'Color:': ' BLACK'}
# {'Size Name:': ' 6x6x6'}
# {'Size:': ' 30'}
# {'Color:': ' Wc0001'}
# {'Color:': ' WC0023'}
# {'Color:': ' Wc0021'}
# {'Color:': ' Wc0022'}
# {'Color:': ' Wc0005'}
# {'Color:': ' WC0015'}
# {'Color:': ' Wc0002'}
# {'Color:': ' Wc0009'}
# {'Color:': ' Wc0026-1'}
# {'Color:': ' Wc0020'}
# {'Color:': ' Wc0068'}
# {'Color:': ' WC0009-1'}
# {'Size:': ' 12 FT'}
# {'Size:': ' 10 FT'}
# {'Size:': ' 8 FT'}
# {'Color:': ' 2.1 CF Washer'}
# {'Color:': ' 1.6 CF Washer'}
# {'Color:': ' 0.9 CF Washer'}
# {'Size:': ' Pack of 2,Standard Packaging'}
# {'Size:': ' M6301037'}
# {'Size:': ' 81BK11001'}
# {'Size:': ' Standard Crib/Toddler'}
# {'Size:': ' M6293012'}
# {'Size:': ' One Size'}
# {'Size:': ' 59" x 65"'}
# {'Size:': ' B207021053'}
# {'Size:': ' B207021044'}
# {'Size:': ' B207021074'}
# {'Size:': ' 81BK7142041'}
# {'Size:': ' B207021159'}
# {'Size:': ' 81BK7141072'}
# {'Size:': ' M6301077'}
# {'Size:': ' M6301081'}
# {'Size:': ' M6301095'}
# {'Size:': ' B207021077'}
# {'Size:': ' B207021022'}
# {'Size:': ' M6301089'}
# {'Size:': ' 81BK7141170'}
# {'Size:': ' M6293004'}
# {'Size:': ' M6301102'}
# {'Size:': ' B207021064'}
# {'Size:': ' Pack of 2'}
# {'Size:': ' M6301085'}
# {'Size:': ' M6301090'}
# {'Size:': ' N/A'}
# {'Size:': ' B207021056'}
# {'Size:': ' Size'}
# {'Size:': ' M6301087'}
# {'Size:': ' 81BK7142135'}
# {'Size:': ' 81BK7141059'}
# {'Size:': ' 1-(4 ct)'}
# {'Size:': ' 1PK'}
# {'Size:': ' 30 in.', 'Color:': ' Stainless-Steel'}
# {'Size:': ' 28 in.', 'Style:': ' 695'}
# {'Size:': ' 34 in.', 'Style:': ' 695'}
# {'Size:': ' 34 in.', 'Style:': ' 698'}
# {'Size:': ' 40 in.', 'Style:': ' 695'}
# {'Size:': ' 48 in.', 'Style:': ' 667'}
# {'Size:': ' 30 in.', 'Style:': ' 455'}
# {'Size:': ' 36 in.', 'Style:': ' 667'}
# {'Size:': ' 30 in.', 'Style:': ' KF1'}
# {'Size:': ' 36 in.', 'Style:': ' 597'}
# {'Size:': ' 40 in.', 'Style:': ' 698'}
# {'Size:': ' 28 in.', 'Style:': ' 698'}
# {'Size:': ' 30 in.', 'Style:': ' 597'}
# {'Size:': ' 36 in.', 'Style:': ' 697'}
# {'Size:': ' 30 in.', 'Style:': ' KL3'}
# {'Size:': ' 36 in.', 'Style:': ' 696'}
# {'Size:': ' 48 in.', 'Style:': ' 697'}
# {'Size:': ' 42 in.', 'Style:': ' KECOMi'}
# {'Size:': ' 30 in.', 'Style:': ' KE2i'}
# {'Size:': ' 54 in.', 'Style:': ' 697i'}
# {'Size:': ' 36 in.', 'Style:': ' KF1'}
# {'Size:': ' 36 in.', 'Style:': ' KN4'}
# {'Size:': ' 36 in.', 'Style:': ' GL5i'}
# {'Size:': ' 30 in.', 'Style:': ' GL9i'}
# {'Size:': ' 36 in.', 'Style:': ' GL2i'}
# {'Size:': ' 36 in.', 'Style:': ' KECOM'}
# {'Size:': ' 30 in.', 'Style:': ' 687'}
# {'Size:': ' 42 in.', 'Style:': ' 697'}
# {'Size:': ' 42 in.', 'Style:': ' 697i'}
# {'Size:': ' 30 in.', 'Style:': ' GL2i'}
# {'Size:': ' 36 in.', 'Style:': ' KE2i'}
# {'Size:': ' 36 in.', 'Style:': ' 697i'}
# {'Size:': ' 30 in.', 'Style:': ' KN4'}
# {'Size:': ' 36 in.', 'Style:': ' KB'}
# {'Size:': ' 48 in.', 'Style:': ' KB'}
# {'Size:': ' 30 in.', 'Style:': ' KB'}
# {'Size:': ' 36 in.', 'Style:': ' KE'}
# {'Size:': ' 42 in.', 'Style:': ' KB'}
# {'Size:': ' 36 in.', 'Style:': ' KZ'}
# {'Size:': ' 42 in.', 'Style:': ' KL2'}
# {'Size:': ' 30 in.', 'Style:': ' KE'}
# {'Size:': ' 48 in.', 'Style:': ' KE'}
# {'Size:': ' 1 Faucet', 'Color:': ' Black'}
# {'Size:': ' 6 sq. feet', 'Color:': ' Black / Stainless Steel'}
# {'Style Name:': ' Original'}
# {'Size:': ' 1 pc'}
# {'Size:': ' 30 inch', 'Style:': ' Stainless steel'}
# {'Style Name:': ' 72% RH Level'}
# {'Style Name:': ' 69% RH Level'}
# {'Style Name:': ' 75% RH Level'}
# {'Style Name:': ' 62% RH Level'}
# {'Size:': ' 36 in.', 'Style:': ' 619'}
# {'Size:': ' 30 in.', 'Style:': ' 617'}
# {'Size:': ' 30 in.', 'Style:': ' 615'}
# {'Size:': ' 36 in.', 'Style:': ' 523'}
# {'Size:': ' 30 in.', 'Style:': ' 685'}
# {'Size:': ' 30 in.', 'Style:': ' 527'}
# {'Size:': ' 36-inch'}
# {'Size:': ' 30-inch'}
# {'Size:': ' 2.5cm', 'Color:': ' Multicolored'}
# {'Color:': ' Metallic Silver'}
# {'Color:': ' Metallic Black'}
# {'Size:': ' 2.1 cu ft', 'Color:': ' Stainless Steel'}
# {'Size:': ' 3.0 cu ft', 'Color:': ' Black'}
# {'Color:': ' Aluminum'}
# {'Color:': ' Non-Programmed'}
# {'Color:': ' Pre-Programmed'}
# {'Size:': ' Medium'}
# {'Size:': ' 30"'}
# {'Size:': ' 36"'}
# {'Size:': ' 4 Pack'}
# {'Size:': ' 150 Cans/36 Wine Bottles'}
# {'Size:': ' 101 Cans/24 Wine Bottles'}
# {'Style:': ' Touch Control'}
# {'Style:': ' Push Control'}
# {'Size:': ' accessory'}
# {'Size:': ' 12 Liners'}
# {'Style:': ' Air Filter'}
# {'Color:': ' Green'}
# {'Color:': ' Coyote Brown'}
# {'Size:': ' 4-Pack'}
# {'Size:': ' 6-Pack'}
# {'Size:': ' High End Panda 1.6cu.ft/11lbs Capacity'}
# {'Size:': ' High End Panda 2.0cu.ft/15lbs Capacity'}
# {'Size:': ' Panda 0.9cu.ft/6.6lbs Capacity'}
# {'Size:': ' Two Pack'}
# {'Size:': ' 3 Filters'}
# {'Size:': ' Panda 2.1cu.ft/15.6lbs Capacity'}
# {'Size:': ' 3 Pack'}
# {'Size:': ' 3 pack'}
# {'Style:': ' Without Water Arrestors'}
# {'Style:': ' With Water Hammer Arrestors'}
# {'Size:': ' 10lbs', 'Color:': ' White'}
# {'Size:': ' 10lbs', 'Color:': ' Blue'}
# {'Size:': ' 36 inch', 'Style:': ' Tempered Glass Visor / Digital Touch'}
# {'Size:': ' 30 inch', 'Style:': ' Tempered Glass Visor / Digital Touch'}
# {'Size:': ' 30 inch', 'Style:': ' Canopy Style / Push Button'}
# {'Color:': ' Green/Red'}
# {'Color:': ' White/Black'}
# {'Style:': ' Roller'}
# {'Size:': ' 2.6 cu. ft'}
# {'Size:': ' 1.5 cu. ft'}
# {'Color:': ' Gray', 'Style Name:': ' Standard Capacity'}
# {'Color:': ' Red', 'Style Name:': ' Large Capacity'}
# {'Color:': ' Gray', 'Style Name:': ' Large Capacity'}
# {'Package Quantity:': ' 1', 'Style Name:': ' Silver'}
# {'Size:': ' 24"-36"'}
# {'Size:': ' 18"-24"'}
# {'Style:': ' 2 Burner'}
# {'Color:': ' Stainless-Steel'}
# {'Style:': ' 2.6 cu.ft. Black'}
# {'Style:': ' 4.4 cu.ft. White All Fridge'}
# {'Style:': ' 4.4 cu.ft. White'}
# {'Style:': ' 4.4 cu.ft. Black'}
# {'Style:': ' 4.4 cu.ft. Black All Fridge'}
# {'Style:': ' 4.4 cu.ft. Steel All Fridge'}
# {'Style:': ' 1.7 cu.ft. All Fridge Black'}
# {'Style:': ' 2.6 cu.ft. White'}
# {'Style:': ' 3.3 cu.ft. Patriotic'}
# {'Style:': ' 3.2 cu.ft. Spotless Steel'}
# {'Style:': ' 3.2 cu.ft. Black'}
# {'Size:': ' 7.0 Cubic Feet'}
# {'Size:': ' 5.0 Cubic Feet'}
# {'Size:': ' 3.5 Cubic Feet'}
# {'Size:': ' 1.7 Cubic Feet'}
# {'Size:': ' 9.2 Cubic Feet', 'Color:': ' Stainless Steel'}
# {'Size:': ' 7.3 cu.ft.', 'Color:': ' White'}
# {'Size:': ' 10.0 cu.ft.', 'Color:': ' White'}
# {'Size:': ' 12.3 cu.ft.', 'Color:': ' White'}
# {'Size:': ' 7.3 cu.ft.', 'Color:': ' Steel'}
# {'Size:': ' 11.0 cu.ft.', 'Color:': ' Red'}
# {'Size:': ' 11.0 cu.ft.', 'Color:': ' Black'}
# {'Size:': ' 9.2 cu.ft.', 'Color:': ' White'}
# {'Size:': ' 7.2 cu.ft.', 'Color:': ' White'}
# {'Size:': ' 8.5 cu.ft.', 'Color:': ' White'}
# {'Size:': ' 4.3 cu.ft.', 'Color:': ' White'}
# {'Size:': ' 3.8 cu.ft.', 'Color:': ' White'}
# {'Size:': ' 3.2 cu.ft.', 'Color:': ' White'}
# {'Size:': ' 1 pack'}
# {'Size:': ' 4 pack'}
# {'Color:': ' No1'}
# {'Color:': ' NO2'}
# {'Color:': ' Tiny Black'}
# {'Size:': ' 1.2 CF'}
# {'Size:': ' 6.9 Cu. Ft.'}
# {'Size:': ' 5.2 Cu. Ft.'}
# {'Size:': ' 3.5 Cu. Ft.'}
# {'Style:': ' GTX 970'}
# {'Style:': ' GTX 980'}
# {'Style:': ' GTX 970 SSC'}
# {'Style:': ' GTX 980 CLASSIFIED'}
# {'Color:': ' Black Stainless Steel'}
# {'Style:': ' Black'}
# {'Size:': ' 9 x 4 x 10.25 inches'}
# {'Scent:': ' hygrometer thermometer'}
# {'Scent:': ' thermometer with probe'}
# {'Scent:': ' new hygrometer thermometer'}
# {'Scent:': ' wireless thermometer with clock'}
# {'Size:': ' 3'}
# {'Package Quantity:': ' 4'}
# {'Package Quantity:': ' 3'}
# {'Package Quantity:': ' 2'}
# {'Size:': ' 1 PACK'}
# {'Size:': ' Quantity 1'}
# {'Color:': ' Grey/Green'}
# {'Color:': ' Teal'}
# {'Color:': ' Pink'}
# {'Size:': ' 5 Ft.'}
# {'Color:': ' Brown'}
# {'Size:': ' 6 Ft.'}
# {'Style:': ' No Legs (Includes Storage Drawer)'}
# {'Style Name:': ' Legs (No Storage Drawer)'}
# {'Size:': ' 3.2 cu.ft', 'Color:': ' Black'}
# {'Size:': ' 4.4 cu. ft.', 'Color:': ' Black'}
# {'Size:': ' 1PACK'}
# {'Size:': ' 3PACK'}
# {'Size:': ' 4 PACK'}
# {'Size:': ' 48"'}
# {'Size:': ' Pack 2'}
# {'Color:': ' Clear'}
# {'Color:': ' Original Version'}
# {'Item Package Quantity:': ' 2', 'Package Quantity:': ' 2'}
# {'Item Package Quantity:': ' 6', 'Package Quantity:': ' 6'}
# {'Item Package Quantity:': ' 3', 'Package Quantity:': ' 3'}
# {'Item Package Quantity:': ' 4', 'Package Quantity:': ' 4'}
# {'Size:': ' 8 inches'}
# {'Size:': ' 36 INCH'}
# {'Size:': ' 30" x 32"'}
# {'Size:': ' 24.5" x 20.5"'}
# {'Style Name:': ' 3 Outdoor'}
# {'Style Name:': ' 2 Indoor & 1 Outdoor'}
# {'Style Name:': ' 3 Indoor'}
# {'Color:': ' CLEAR'}
# {'Color:': ' WHITE'}
# {'Color:': ' UKF7002AXX Refrigerator Water Filter'}
# {'Color:': ' Black/Stainless Steel'}
# {'Color:': ' White/Stainless Steel'}
# {'Size:': ' Single Unit'}
# {'Color:': ' Stainless-steel'}
# {'Size:': ' 4PACK'}
# {'Size:': ' 2PACK'}
# {'Color:': ' Black Authentic'}
# {'Color:': ' Preserve'}
# {'Size:': ' 10.0 cu.ft.', 'Color:': ' Black'}
# {'Size:': ' 10-pack'}
# {'Size:': ' PAULTRA'}
# {'Size:': ' EAFCBF'}
# {'Size:': ' 12 ft., Pair', 'Color:': ' Black'}
# {'Size:': ' 8 ft., Pair', 'Color:': ' Black'}
# {'Pattern:': ' 279640'}
# {'Size:': ' Celsius (C)', 'Color:': ' Black'}
# {'Size:': ' Fahrenheit (F)', 'Color:': ' White'}
# {'Size:': ' Fahrenheit (F)', 'Color:': ' Black'}
# {'Size:': ' Celsius (C)', 'Color:': ' White'}
# {'Size:': ' 5.1 cubic-feet', 'Color:': ' Black'}
# {'Size:': ' Single'}
# {'Size:': ' 4"/8\''}
# {'Color:': ' RED'}
# {'Size:': ' 4'}
# {'Size:': ' 200 Photos'}
# {'Color:': ' Stackable Holder - 2 Liter'}
# {'Color:': ' Soda Can Bin'}
# {'Size:': ' Pair', 'Color:': ' Brown'}
# {'Size:': ' Black, 8 ft., Single', 'Color:': ' Black'}
# {'Size:': ' Black, 8 ft., Pair', 'Color:': ' Black'}
# {'Size:': ' 15.74"*4', 'Color:': ' Gray'}
# {'Size:': ' 15.74"*4', 'Color:': ' Red'}
# {'Size:': ' 15.74"*4', 'Color:': ' Big Red'}
# {'Size:': ' 15.74"*4', 'Color:': ' Black'}
# {'Color:': ' red'}
# {'Size:': ' 15.7"*4"', 'Color:': ' Circle'}
# {'Size:': ' 4 Pack', 'Package Quantity:': ' 1'}
# {'Color:': ' Ivory'}
# {'Package Quantity:': ' 6'}
# {'Size:': ' 2 Faucet without Kegs', 'Color:': ' Stainless Steel'}
# {'Size:': ' MS6508-2'}
# {'Size:': ' 1-pack'}
# {'Size:': ' 36 in.', 'Color:': ' Embossed Copper'}
# {'Size:': ' 30 in.', 'Style:': ' 8KBE'}
# {'Size:': ' 46 in.', 'Style:': ' 8KBB'}
# {'Size:': ' CF0002'}
# {'Size:': ' 2 Filters'}
# {'Size:': ' Panda 3.75 Cu.ft'}
# {'Size:': ' Panda 7 Serial 3.75 Cu.ft Bottom Control'}
# {'Size:': ' 20 Pack'}
# {'Size:': ' 25 Pack'}
# {'Style:': ' Humiditrak'}
# {'Size:': ' 5.5-6 lbs', 'Color:': ' Light Blue'}
# {'Size:': ' 17.6lbs- Blue+ White'}
# {'Size:': ' 16lbs- Gray+ White'}
# {'Size:': ' 8 Filters'}
# {'Color:': ' Stainless Steel / Black'}
# {'Color:': ' Black / Stainless Steel'}
# {'Color:': ' Stainless Steel / LCD'}
# {'Size:': ' 96-can'}
# {'Size:': ' 175-can'}
# {'Size:': ' 2.50in. x 2.50in. x 2.00in.'}
# {'Size:': ' 2.50in. x 2.50in. x 1.75in.'}
# {'Size:': ' 20.10in. x 6.90in. x 6.90in.'}
# {'Size:': ' As shown in the image'}
# {'Size:': ' 6.50in. x 6.50in. x 2.00in.'}
# {'Size:': ' 30" Tempered Glass'}
# {'Size:': ' 1 pcs'}
# {'Size:': ' 2 Pack', 'Style Name:': ' Advanced'}
# {'Size:': ' 1 Pack', 'Style Name:': ' Standard'}
# {'Size:': ' 6', 'Style Name:': ' 6 Pack'}
# {'Size:': ' 4 Pack', 'Style Name:': ' Standard'}
# {'Size:': ' 3 Pack', 'Style Name:': ' Advanced'}
# {'Size Name:': ' 3 Pack'}
# {'Size:': ' 2 Pack', 'Style Name:': ' Standard'}
# {'Size:': ' 1 Pack', 'Style Name:': ' Plus'}
# {'Size:': ' 2'}
# {'Size:': ' 3 Pack', 'Style:': ' Plus'}
# {'Size:': ' 3 Pack', 'Style:': ' Standard'}
# {'Size:': ' 4 Pack', 'Style:': ' Standard'}
# {'Size:': ' 2 Pack', 'Style:': ' Standard'}
# {'Size:': ' 1 Pack', 'Style:': ' Standard'}
# {'Size:': ' 3 Pack', 'Style:': ' Advanced'}
# {'Size:': ' 1 Unit'}
# {'Size:': ' 21 Inches', 'Color:': ' Black'}
# {'Size:': ' 21 Inches', 'Color:': ' semi-clear'}
# {'Size:': ' 21 Inches', 'Color:': ' White'}
# {'Size:': ' Small'}
# {'Size:': ' 16 Pack'}
# {'Size:': ' 2 Pack -White'}
# {'Size:': ' 3 Pack of Filters'}
# {'Pattern:': ' 3949247'}
# {'Style Name:': ' 2 Indoor/1 Outdoor'}
# {'Size:': ' 6ft'}
# {'Size:': ' 4 Foot'}
# {'Style:': ' 800 CFM'}
# {'Style:': ' 900 CFM'}
# {'Package Quantity:': ' 36'}
# {'Package Quantity:': ' 12'}
# {'Package Quantity:': ' 45'}
# {'Package Quantity:': ' 20'}
# {'Color:': ' Off-white'}
# {'Color:': ' Black With Stainless'}
# {'Color:': ' Candy Apple Red'}
# {'Size:': ' 36-inch', 'Style:': ' Plus'}
# {'Size:': ' 4 in. x 8 ft.'}
# {'Size:': ' 4 in. x 20 ft.'}
# {'Size:': ' 4pcs'}
# {'Style Name:': ' Standard'}
# {'Size:': ' 3 Pack', 'Style Name:': ' Standard'}
# {'Size:': ' 6 Pack'}
# {'Size:': ' 6 Pack', 'Style:': ' Standard'}
# {'Size:': ' Pack of 3'}
# {'Size:': " 7' - 8.5' Ceiling"}
# {'Size:': " 8' - 9' Ceiling"}
# {'Size:': ' 90 Can'}
# {'Size:': ' 126 Can'}
# {'Size:': ' 126 Can (Black)'}
# {'Size:': ' 1 Pack', 'Style:': ' Plus'}
# {'Size:': ' 2 Pack', 'Style:': ' Plus'}
# {'Size Name:': ' 2 Pack', 'Style:': ' Premium'}
# {'Size Name:': ' 1 Pack', 'Style:': ' Premium-1 Pack'}
# {'Color:': ' LED Display'}
# {'Size:': ' 3.0 cu. ft', 'Color:': ' Stainless Steel'}
# {'Style Name:': ' Indoor Thermometer & Hygrometer'}
# {'Style Name:': ' Indoor Outdoor Thermometer & Hygrometer'}
# {'Size:': ' 7-Gallon'}
# {'Size:': ' 24 Inch'}
# {'Size:': ' 100-Bottle'}
# {'Color:': ' 8.75'}
# {'Size:': ' 36-Inch, Satin Aluminum'}
# {'Size:': ' 30-Inch, Satin Aluminum'}
# {'Size Name:': ' 24-Inch'}
# {'Size:': ' 72 Inch'}
# {'Size:': ' 8-Inch', 'Color:': ' Black'}
# {'Size:': ' 6-Inch', 'Color:': ' Chrome'}
# {'Size:': ' 1200 CFM 3-Amp'}
# {'Size:': ' 4X Large'}
# {'Size:': ' 30-Inch 450 CFM'}
# {'Size:': ' 400 CFM', 'Color:': ' Silver'}
# {'Size:': ' 290 CFM', 'Color:': ' stainless-steel'}
# {'Size:': ' 3/8" 10FT Long'}
# {'Color:': ' Thunder Gray'}
# {'Size:': ' 83-lbs Capacity'}
# {'Size:': ' 65-lb Capacity'}
# {'Size:': ' 48" - 86"'}
# {'Size:': ' 48-inch by 86-inch'}
# {'Size:': ' 86-inch by 120-inch'}
# {'Color:': ' Polar White'}
# {'Size:': ' 10 x 36 Inch'}
# {'Size:': ' 600 CFM'}
# {'Color:': ' Brushed Aluminum'}
# {'Color:': ' silver mist'}
# {'Color:': ' Tuscan Grapes'}
# {'Size:': ' Right Hinge', 'Color:': ' Stainless Steel', 'Style:': ' Under Counter, Clear Ice'}
# {'Size:': ' Left Hinge', 'Color:': ' Stainless Steel', 'Style:': ' Outdoor, Under Counter, Clear Ice'}
# {'Size:': ' Right Hinge', 'Color:': ' Stainless Steel', 'Style:': ' Under Counter, Clear Ice w/Pump'}
# {'Size:': ' 174'}
# {'Size:': ' '}
# {'Size:': ' 12VDC'}
# {'Color:': ' Black on Black'}
# {'Size:': ' 48 Inch'}
# {'Color:': ' Brushed Nickel'}
# {'Size:': ' 30" 600 CFM'}
# {'Color:': ' Proverbs 3'}
# {'Size:': ' 4 ft Length'}
# {'Size:': ' 30 inch', 'Color:': ' Stainless Steel'}
# {'Size:': ' 30 inch', 'Color:': ' White'}
# {'Size:': ' 9OZ', 'Color:': ' Silver'}
# {'Color:': ' Polished Nickel'}
# {'Color:': ' Brass'}
# {'Size:': ' 4" Dia. Pipe'}
# {'Size:': ' 30 in.', 'Style:': ' GL14i'}
# {'Size:': ' 60 in.', 'Style:': ' KECOMi'}
# {'Size:': ' 36 inch', 'Style:': ' Stainless steel'}
# {'Style Name:': ' Homemade Pantry'}
# {'Size:': ' 36-Inch', 'Style:': ' RAX9436SQB-1'}
# {'Size:': ' 30 in.', 'Style:': ' 621'}
# {'Size:': ' 292cfm'}
# {'Size:': ' 450cfm'}
# {'Size:': ' 400 CFM', 'Color:': ' Stainless Steel'}
# {'Color:': ' Metallic Red'}
# {'Size:': ' RH0009'}
# {'Size:': ' 24"'}
# {'Size:': ' Universal'}
# {'Color:': ' green'}
# {'Pattern:': ' Chlorine'}
# {'Size:': ' 18.5" DEEP 600 CFM'}
# {'Size:': ' C14 w Fuse Green Light'}
# {'Length:': ' 5pcs C14 w Fuse Red Light'}
# {'Color:': ' Stainless Steel / Glass'}
# {'Color:': ' brown, red'}
# {'Size:': ' 20" Length X 20" Width'}
# {'Size:': ' -40 to 220 degree F, 0.01 degree Resolution, 0.4 degree C Accuracy'}
# {'Size:': " 4'3 Dryer", 'Style:': ' 30 Amp'}
# {'Package Quantity:': ' 50'}
# {'Package Quantity:': ' 25'}
# {'Size:': ' 36-Inch', 'Style:': ' ISX2136SQB-1'}
# {'Size:': ' 1/4 Inch'}
# {'Size:': ' 42 in.', 'Style:': ' 667-304'}
# {'Size:': ' X-Small'}
# {'Size:': ' 3.1 cu ft', 'Color:': ' Black'}
# {'Color:': ' Yellow Gold'}
# {'Size:': ' 30 in.', 'Style:': ' 8667C'}
# {'Size:': ' 30 in.', 'Style:': ' 8667E'}
# {'Design:': ' 349241t'}
# {'Size:': ' Large', 'Color:': ' Black'}
# {'Color:': ' White Cabinet and White Door', 'Style:': ' Right Hinge Door'}
# {'Format:': ' Vinyl'}
# {'Size:': ' 24"', 'Color:': ' Right Hinge'}
# {'Size:': ' 4 Faucet without Kegs', 'Color:': ' Black'}
# {'Size Name:': ' 30"w x 16"h Left Side Vent*'}
# {'Size:': ' 2.5 inch square', 'Color:': ' Yellow Grey'}
# {'Size:': ' 30 in.', 'Color:': ' Embossed Copper'}
# {'Size:': ' 30 in.', 'Color:': ' Black Copper'}
# {'Style:': ' W/ Vertical Vent Kit'}
# {'Size:': ' CF0001'}
# {'Size:': ' 36-Inch', 'Style:': ' IN2636SQB-650-5'}
# {'Size:': ' 50', 'Color:': ' Tan'}
# {'Size:': ' Carbon Filter'}
# {'Size:': ' 6.7 Cu ft'}
# {'Size:': ' 300 cans'}
# {'Size:': ' 450 cans'}
# {'Size:': ' 17 Feet'}
# {'Size:': ' 6.25in. x 6.00in. x 3.00in.'}
# {'Size:': ' 140 cans', 'Style:': ' 1 Doors'}
# {'Size:': ' 169 cans', 'Style:': ' 2 Doors'}
# {'Size:': ' Regular Dryer'}
# {'Size:': ' Adult', 'Color:': ' Blue'}
# {'Size:': ' CF0006'}
# {'Size:': ' Indoor&Outdoor temp.', 'Color:': ' White'}
# {'Color:': ' Temperature&humidity Meter(gray)'}
# {'Color:': ' Temperature Meter(black)'}
# {'Size:': ' 600-Pack', 'Style:': ' 4 g 55%'}
# {'Size:': ' 600-Pack', 'Style:': ' 4 g 62%'}
# {'Size:': ' MS6508'}
# {'Size:': ' 30 in.', 'Style:': ' 373AA'}
# {'Size:': ' 30 in.', 'Style:': ' KBCRN'}
# {'Size:': ' 48 in.', 'Style:': ' KL2CRN'}
# {'Size:': ' 28 in.', 'Style:': ' 695-RS'}
# {'Size:': ' 42 in.', 'Style:': ' 697i-RS'}
# {'Size:': ' 36 in.', 'Style:': ' 597i-RD'}
# {'Size:': ' 30-inch', 'Color:': ' Stainless Steel'}
# {'Size:': ' 36-inch', 'Color:': ' Stainless Steel'}
# {'Size:': ' 28-inch', 'Style:': ' Plus'}
# {'Size:': ' 1 Pack', 'Style Name:': ' Deluxe'}
# {'Color:': ' Galvanized'}
# {'Size:': ' 1D'}

# %%
# Basic Data visualisation

# %%
# Histogram for overall ratings
plt.hist(df['overall'], bins = [0.5, 1.5, 2.5, 3.5, 4.5, 5.5], edgecolor = 'black', rwidth = 0.8)
plt.xlabel('Overall Rating')
plt.ylabel('Frequency')
plt.title('Distribution of Overall Ratings')
plt.xticks(range(1, 6))
plt.show()

# %%
# Bar plot for verified status
verified_counts = df['verified'].value_counts()
plt.bar(verified_counts.index, verified_counts.values)
plt.xlabel('Verified Status')
plt.ylabel('Count')
plt.title('Distribution of Verified and Unverified Reviews')
plt.xticks([False, True], ['Unverified', 'Verified'])
plt.show()

# %%
# Time Series Plot for Reviews Over the Years
sns.set_style('whitegrid')
plt.figure(figsize=(10, 5))
sns.lineplot(x='reviewYear', y='overall', data=df, estimator=len)
plt.xlabel('Year')
plt.ylabel('Number of Reviews')
plt.title('Reviews Over the Years')
plt.show()
# Out:
# c:\Users\Scratticus\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Scratticus\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Scratticus\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Scratticus\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Scatter Plot for overall ratings vs. vote
plt.scatter(df['overall'], df['vote'], alpha = 0.5)
plt.xlabel('Overall Rating')
plt.ylabel('Number of Votes')
plt.title('Overall Rating vs. Number of Votes')
plt.xticks(range(1, 6))
plt.show()

# %%
# Box plot for overall ratings vs. vote
plt.boxplot([df[df['overall'] == rating]['vote'] for rating in range(1, 6)], labels=range(1, 6))
plt.xlabel('Overall Rating')
plt.ylabel('Number of Votes')
plt.title('Box Plot of Overall Rating vs. Number of Votes')
plt.show()

# %%
# Violin Plot for overall Ratings vs. vote
sns.violinplot(x = 'overall', y = 'vote', data = df, inner = 'quartile', palette = 'Set3')
plt.xlabel('Overall Rating')
plt.ylabel('Number of Votes')
plt.title('Violin Plot of Overall Rating vs. Number of Votes')
plt.show()
# Out:
# c:\Users\Scratticus\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Scratticus\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Scratticus\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Heatmap for Correlation
numerical_columns = ['overall', 'vote', 'unixReviewTime', 'reviewYear', 'reviewMonth', 'reviewDay']
correlation_matrix = df[numerical_columns].corr()

sns.heatmap(correlation_matrix, annot = True, cmap = 'coolwarm', fmt = ".2f", linewidths = 0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Word cloud to visualize the most common words in reviewText

# Concatenate all reviewText entries into one text
review_text = ' '.join(df['reviewText'].astype(str))

# Create a WordCloud object
wordcloud_revText = WordCloud(width = 800, height = 400, background_color = 'white', colormap = 'viridis').generate(review_text)

# Display the word cloud
plt.imshow(wordcloud_revText, interpolation = 'bilinear')
plt.axis('off')
plt.title('Word Cloud for reviewText')
plt.show()

# %%
# Word cloud to visualize the most common words in summary

# Concatenate all reviewText entries into one text
summary_text = ' '.join(df['summary'].astype(str))

# Create a WordCloud object
wordcloud_sum = WordCloud(width = 800, height = 400, background_color = 'white', colormap = 'viridis').generate(summary_text)

# Display the word cloud
plt.imshow(wordcloud_sum, interpolation = 'bilinear')
plt.axis('off')
plt.title('Word Cloud for reviewText')
plt.show()

# %%
df.to_csv('../data/appliances.csv', index=False)
